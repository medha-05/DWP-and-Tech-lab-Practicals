# %% [markdown]
# <a href="https://colab.research.google.com/github/medha-05/DWP-and-Tech-lab-Practicals/blob/main/DWP_Prac_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NORMALISATION:
# # A NORMALISATION IS A SCALING TECHNIQUE IN WHICH VALUES ARE SHIFTED AND RESCALED RANGING BETWEEN 0 AND 1. IT IS ALSO KNOWN AS MEAN MAX SCALAR.
#
# # FORMULA:
#  # Xsc = (X − Xmin) / (Xmax − Xmin)

# %% [markdown]
# # STANDARDISATION:
# # 1. IT IS A SCALING TECHNIQUE.
# # 2. IN THIS VALUES ARE CENTERED AROURD THE MEAN WITH A UNIQUE STANDARD DEVIATION.
#
# # FORMULA:
# #  x' = (x - mu)/ sigma
#
# # 3. IF OUR DATA IS NOT NORMALLY DISTRIBUTED, THEN WE USE NORMALIZATION.
#
# # factor analysis, reduction technique

# %%
# Import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, RobustScaler, Normalizer

# %%
data = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/refs/heads/master/BostonHousing.csv')
data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
scalar = MinMaxScaler()
normalise_data = scalar.fit_transform(data)
normalise_data
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#         1.00000000e+00, 8.96799117e-02, 4.22222222e-01],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         1.00000000e+00, 2.04470199e-01, 3.68888889e-01],
#        [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         9.89737254e-01, 6.34657837e-02, 6.60000000e-01],
#        ...,
#        [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.07891832e-01, 4.20000000e-01],
#        [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#         9.91300620e-01, 1.31070640e-01, 3.77777778e-01],
#        [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.69701987e-01, 1.53333333e-01]])

# %%
# Convert to dataframe
new_data = pd.DataFrame(normalise_data, columns=data.columns)
new_data
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %%
new_data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.040544    0.113636    0.391378    0.069170    0.349167    0.521869
# std      0.096679    0.233225    0.251479    0.253994    0.238431    0.134627
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000851    0.000000    0.173387    0.000000    0.131687    0.445392
# 50%      0.002812    0.000000    0.338343    0.000000    0.314815    0.507281
# 75%      0.041258    0.125000    0.646628    0.000000    0.491770    0.586798
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.676364    0.242381    0.371713    0.422208    0.622929    0.898568
# ...

# %%
scalar = StandardScaler()
std_data = scalar.fit_transform(data)
std_data
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ...,  0.44105193,
#         -1.0755623 ,  0.15968566],
#        [-0.41733926, -0.48772236, -0.59338101, ...,  0.44105193,
#         -0.49243937, -0.10152429],
#        [-0.41734159, -0.48772236, -0.59338101, ...,  0.39642699,
#         -1.2087274 ,  1.32424667],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  0.44105193,
#         -0.98304761,  0.14880191],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  0.4032249 ,
#         -0.86530163, -0.0579893 ],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  0.44105193,
#         -0.66905833, -1.15724782]])

# %%
# Convert to dataframe
new_data1 = pd.DataFrame(std_data, columns=data.columns)
new_data1
# Out:
#          crim        zn     indus      chas       nox        rm       age  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...

# %%
new_data1.describe()
# Out:
#                crim            zn         indus          chas           nox  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean  -1.123388e-16  7.898820e-17  2.106352e-16 -3.510587e-17 -1.965929e-16
# std    1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00
# min   -4.197819e-01 -4.877224e-01 -1.557842e+00 -2.725986e-01 -1.465882e+00
# 25%   -4.109696e-01 -4.877224e-01 -8.676906e-01 -2.725986e-01 -9.130288e-01
# 50%   -3.906665e-01 -4.877224e-01 -2.110985e-01 -2.725986e-01 -1.442174e-01
# 75%    7.396560e-03  4.877224e-02  1.015999e+00 -2.725986e-01  5.986790e-01
# max    9.933931e+00  3.804234e+00  2.422565e+00  3.668398e+00  2.732346e+00
#
#                  rm           age           dis           rad         tax  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  506.000000
# mean  -1.088282e-16 -1.474446e-16 -8.425408e-17 -1.123388e-16    0.000000
# ...

# %% [markdown]
# # MEAN NORMALISATION:
#
# # FORMULA:
# #  (X − Mean) / (Xmax − Xmin)

# %%
# Calculate mean normalisation:
mean = data.mean()
mean
# Out:
# crim         3.613524
# zn          11.363636
# indus       11.136779
# chas         0.069170
# nox          0.554695
# rm           6.284634
# age         68.574901
# dis          3.795043
# rad          9.549407
# tax        408.237154
# ptratio     18.455534
# b          356.674032
# lstat       12.653063
# medv        22.532806
# dtype: float64

# %%
mean1 = (data - data.mean())/(data.max() - data.min())
mean1
# Out:
#          crim        zn     indus     chas       nox        rm       age  \
# 0   -0.040544  0.066364 -0.323562 -0.06917 -0.034352  0.055636 -0.034757
# 1   -0.040308 -0.113636 -0.149075 -0.06917 -0.176327  0.026129  0.106335
# 2   -0.040308 -0.113636 -0.149075 -0.06917 -0.176327  0.172517 -0.076981
# 3   -0.040251 -0.113636 -0.328328 -0.06917 -0.198961  0.136686 -0.234551
# 4   -0.039839 -0.113636 -0.328328 -0.06917 -0.198961  0.165236 -0.148042
# ..        ...       ...       ...      ...       ...       ...       ...
# 501 -0.039911 -0.113636  0.029077 -0.06917  0.037664  0.059085  0.005408
# 502 -0.040106 -0.113636  0.029077 -0.06917  0.037664 -0.031545  0.083678
# 503 -0.039932 -0.113636  0.029077 -0.06917  0.037664  0.132471  0.230948
# 504 -0.039383 -0.113636  0.029077 -0.06917  0.037664  0.097598  0.213441
# 505 -0.040082 -0.113636  0.029077 -0.06917  0.037664 -0.048790  0.125902
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...

# %%
# MAXIMUM ABSOLUTE SCALAR:
scalar = MaxAbsScaler()
max_data = scalar.fit_transform(data)
max_data
# Out:
# array([[7.10302306e-05, 1.80000000e-01, 8.32732516e-02, ...,
#         1.00000000e+00, 1.31156176e-01, 4.80000000e-01],
#        [3.06936012e-04, 0.00000000e+00, 2.54866619e-01, ...,
#         1.00000000e+00, 2.40716355e-01, 4.32000000e-01],
#        [3.06711233e-04, 0.00000000e+00, 2.54866619e-01, ...,
#         9.89745528e-01, 1.06136423e-01, 6.94000000e-01],
#        ...,
#        [6.82879242e-04, 0.00000000e+00, 4.30064888e-01, ...,
#         1.00000000e+00, 1.48538320e-01, 4.78000000e-01],
#        [1.23167768e-03, 0.00000000e+00, 4.30064888e-01, ...,
#         9.91307634e-01, 1.70661048e-01, 4.40000000e-01],
#        [5.32839119e-04, 0.00000000e+00, 4.30064888e-01, ...,
#         1.00000000e+00, 2.07532262e-01, 2.38000000e-01]])

# %%
# Convert to dataframe
new_data2 = pd.DataFrame(max_data, columns=data.columns)
new_data2
# Out:
#          crim    zn     indus  chas       nox        rm    age       dis  \
# 0    0.000071  0.18  0.083273   0.0  0.617681  0.748861  0.652  0.337278
# 1    0.000307  0.00  0.254867   0.0  0.538462  0.731321  0.789  0.409607
# 2    0.000307  0.00  0.254867   0.0  0.538462  0.818337  0.611  0.409607
# 3    0.000364  0.00  0.078587   0.0  0.525832  0.797039  0.458  0.499913
# 4    0.000776  0.00  0.078587   0.0  0.525832  0.814009  0.542  0.499913
# ..        ...   ...       ...   ...       ...       ...    ...       ...
# 501  0.000704  0.00  0.430065   0.0  0.657865  0.750911  0.691  0.204395
# 502  0.000509  0.00  0.430065   0.0  0.657865  0.697039  0.767  0.188636
# 503  0.000683  0.00  0.430065   0.0  0.657865  0.794533  0.910  0.178741
# 504  0.001232  0.00  0.430065   0.0  0.657865  0.773804  0.893  0.196998
# 505  0.000533  0.00  0.430065   0.0  0.657865  0.686788  0.808  0.206572
#
#           rad       tax   ptratio         b     lstat   medv
# ...

# %%
new_data2.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.040612    0.113636    0.401470    0.069170    0.636849    0.715790
# std      0.096672    0.233225    0.247309    0.253994    0.133040    0.080025
# min      0.000071    0.000000    0.016583    0.000000    0.442021    0.405581
# 25%      0.000922    0.000000    0.187094    0.000000    0.515499    0.670330
# 50%      0.002883    0.000000    0.349315    0.000000    0.617681    0.707118
# 75%      0.041327    0.125000    0.652487    0.000000    0.716418    0.754385
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.685749    0.312954    0.397892    0.574173    0.838888    0.898650
# ...

# %% [markdown]
# # MEDIAN AND QUARTILE NORMALISATION SCALING:
#
# # (x - median(x)) / (IQR(x))

# %%
# MEDIAN AND QUARTILE SCALING:
scalar = RobustScaler()
med_data = scalar.fit_transform(data)
med_data
# Out:
# array([[-0.06959315,  1.44      , -0.57164988, ...,  0.26190191,
#         -0.63768116,  0.35109718],
#        [-0.06375455,  0.        , -0.20294345, ...,  0.26190191,
#         -0.22188906,  0.05015674],
#        [-0.06376011,  0.        , -0.20294345, ...,  0.06667466,
#         -0.73263368,  1.69278997],
#        ...,
#        [-0.05445006,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.57171414,  0.33855799],
#        [-0.04086745,  0.        ,  0.17350891, ...,  0.09641444,
#         -0.48775612,  0.10031348],
#        [-0.05816351,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.34782609, -1.1661442 ]])

# %%
# Convert to dataframe
new_data3 = pd.DataFrame(med_data, columns=data.columns)
new_data3
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0   -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1   -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2   -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3   -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4   -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501 -0.053930  0.00  0.173509   0.0  0.200000  0.521003 -0.171254 -0.236007
# 502 -0.058759  0.00  0.173509   0.0  0.200000 -0.119919 -0.016310 -0.297887
# 503 -0.054450  0.00  0.173509   0.0  0.200000  1.039973  0.275229 -0.336744
# 504 -0.040867  0.00  0.173509   0.0  0.200000  0.793360  0.240571 -0.265053
# 505 -0.058164  0.00  0.173509   0.0  0.200000 -0.241870  0.067278 -0.227459
#
# ...

# %%
new_data3.describe()
# Out:
#                crim          zn       indus        chas         nox  \
# count  5.060000e+02  506.000000  506.000000  506.000000  506.000000
# mean   9.337910e-01    0.909091    0.112067    0.069170    0.095400
# std    2.392616e+00    1.865796    0.531398    0.253994    0.662158
# min   -6.959315e-02    0.000000   -0.714950    0.000000   -0.874286
# 25%   -4.852940e-02    0.000000   -0.348567    0.000000   -0.508571
# 50%   -7.697835e-18    0.000000    0.000000    0.000000    0.000000
# 75%    9.514706e-01    1.000000    0.651433    0.000000    0.491429
# max    2.467838e+01    8.000000    1.398141    1.000000    1.902857
#
#                rm         age           dis         rad         tax  \
# count  506.000000  506.000000  5.060000e+02  506.000000  506.000000
# mean     0.103163   -0.181959  1.902672e-01    0.227470    0.202163
# std      0.952056    0.573881  6.818457e-01    0.435363    0.435496
# min     -3.587398   -1.520897 -6.728244e-01   -0.200000   -0.369509
# ...

# %% [markdown]
# # Regularisation Technique:
# # L2 regularisation is also called as RIDGE regularisation. It prevents the overfitting problem by adding penalty to loss function. This penalty discourage large coefficients in the model.

# %%
# Vector Unit Length Scaling using L2 Norm:

normalizer_data = Normalizer(norm='l2')
unit_data = scalar.fit_transform(data)
unit_data
# Out:
# array([[-0.06959315,  1.44      , -0.57164988, ...,  0.26190191,
#         -0.63768116,  0.35109718],
#        [-0.06375455,  0.        , -0.20294345, ...,  0.26190191,
#         -0.22188906,  0.05015674],
#        [-0.06376011,  0.        , -0.20294345, ...,  0.06667466,
#         -0.73263368,  1.69278997],
#        ...,
#        [-0.05445006,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.57171414,  0.33855799],
#        [-0.04086745,  0.        ,  0.17350891, ...,  0.09641444,
#         -0.48775612,  0.10031348],
#        [-0.05816351,  0.        ,  0.17350891, ...,  0.26190191,
#         -0.34782609, -1.1661442 ]])

# %%
# Convert to dataframe
new_data4 = pd.DataFrame(unit_data, columns=data.columns)
new_data4
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0   -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1   -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2   -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3   -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4   -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501 -0.053930  0.00  0.173509   0.0  0.200000  0.521003 -0.171254 -0.236007
# 502 -0.058759  0.00  0.173509   0.0  0.200000 -0.119919 -0.016310 -0.297887
# 503 -0.054450  0.00  0.173509   0.0  0.200000  1.039973  0.275229 -0.336744
# 504 -0.040867  0.00  0.173509   0.0  0.200000  0.793360  0.240571 -0.265053
# 505 -0.058164  0.00  0.173509   0.0  0.200000 -0.241870  0.067278 -0.227459
#
# ...
