# %% [markdown]
# <a href="https://colab.research.google.com/github/medha-05/DWP-and-Tech-lab-Practicals/blob/main/Tech_lab_Prac_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MatthewCarterIO/car-evaluation-ML/refs/heads/master/car.data.csv')

# %%
df.shape
# Out:
# (1727, 7)

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
df.columns = col_names
col_names
# 1. buying price
# 2. maintainace cost
# 3. number of doors
# 4. no of persons
# 5. lug_boot size
# 6. safety
# 7. class
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   vhigh    1727 non-null   object
#  1   vhigh.1  1727 non-null   object
#  2   2        1727 non-null   object
#  3   2.1      1727 non-null   object
#  4   small    1727 non-null   object
#  5   low      1727 non-null   object
#  6   unacc    1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.isnull().sum()
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %%
df.describe()
# Out:
#        vhigh vhigh.1     2   2.1 small   low  unacc
# count   1727    1727  1727  1727  1727  1727   1727
# unique     4       4     4     3     3     3      4
# top     high    high     3     4   med   med  unacc
# freq     432     432   432   576   576   576   1209

# %%
df['class'].value_counts()
# Out:
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
X = df.drop(['class'], axis=1)
y = df['class']

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
for col in col_names:
    print(df[col].value_counts())
# Out:
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# doors
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: count, dtype: int64
# persons
# 4       576
# more    576
# 2       575
# Name: count, dtype: int64
# lug_boot
# med      576
# big      576
# small    575
# Name: count, dtype: int64
# safety
# med     576
# high    576
# low     575
# Name: count, dtype: int64
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
df['class'].value_counts()
# Out:
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
# Split X and y into training and testing sets

from sklearn.model_selection import train_test_split
X_train, X_test, y_test, y_train = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
# !pip install category_encoders
import category_encoders as ce
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 87.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.0
#     Uninstalling scikit-learn-1.6.0:
#       Successfully uninstalled scikit-learn-1.6.0
# ...

# %%
encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])
X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:411: FutureWarning: The `_get_tags` method is deprecated in 1.6 and will be removed in 1.7. Please implement the `__sklearn_tags__` method.
#   warnings.warn(

# %%
X_train
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 83         1      1      1        1         1       1
# 48         1      1      2        2         1       2
# 468        2      1      2        3         2       2
# 155        1      2      2        2         1       1
# 1043       3      2      3        2         2       1
# ...      ...    ...    ...      ...       ...     ...
# 1130       3      3      2        2         3       1
# 1294       3      4      1        2         3       3
# 860        2      4      1        2         3       1
# 1459       4      2      3        1         2       3
# 1126       3      3      2        2         2       3
#
# [1157 rows x 6 columns]
